# %%
# Author: Anonymous
# project: pulmonary disease classification


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
import matplotlib.pyplot as plt
import glob
from tqdm import tqdm
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from skimage import io, transform
from keras.utils import to_categorical
import time
from sklearn.model_selection import train_test_split
seed = 333
np.random.seed(seed)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input/pulmonary-chest-xray-abnormalities"))

# Any results you write to the current directory are saved as output.
# Out:
# ['ChinaSet_AllFiles', 'Montgomery']

# %%
kbase = os.listdir("../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/CXR_png")
kbase1 = os.listdir("../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/ClinicalReadings")
for filet in kbase1:
    f = open("../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/ClinicalReadings/"+filet, 'r')
    file_contents = f.read()
    file_con_list = file_contents.split("\n")
    file_con_list = file_con_list[-1]
    print(file_con_list)
imle = cv2.imread("../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/CXR_png/CHNCXR_0507_1.png")
plt.imshow(imle)
plt.show()
# Out:
# normal
# left PTB
# normal
# PTB in the right upper field
# normal
# PTB in the right lower field
# PTB in the right upper field
# secondary PTB  in the left upper field
# right upper PTB
# normal
# normal
# normal
# normal
# normal
#
# Right PTB
# normal
# normal
# normal
# normal
# normal
# bilateral secondary PTB  with right pneumothorax
# normal
# normal
# bilateral secondary PTB  with right pleural thickening
# right upper PTB
# normal
# Right PTB
# normal
# secondary PTB  in the left upper field
# PTB in the right upper field
# normal
# 1.secondary PTB  in the right upper field; 2.small tuberculoma; 3.right pleural thickening and adhesions
# tuberculosis pleuritis
# Right PTB
# bilateral PTB
# STB
# PTB in the right upper field
# normal
# left PTB
# normal
# left PTB
# bilateral secondary PTB  with pleural thickening
# left PTB
# normal
# normal
# normal
# normal
# bilateral PTB
# Right PTB
# secondary PTB  in the right upper field
# PTB in the right upper field
# normal
# bilateral PTB
# normal
# normal
# Right PTB
# normal
# normal
# Right PTB
# normal
# Left secondary PTB in the upper and middle fields, mainly  fibrous  lesions
# secondary PTB  in the left upper field
# Right PTB
# normal
# bilateral PTB
# PTB in the left upper field
# normal
# PTB in the left upper field
# normal
# normal
# normal
# bilateral PTB
# normal
# Bilateral secondary PTB with left lower field pneumonia
# left upper PTB, left pleurisy
# normal
# PTB in the left lower field
# right secondary PTB
# PTB in the right upper field
# normal
# bilateral PTB
# normal
# PTB in the left upper field
# normal
# bilateral PTB
# right secondary PTB  with bilateral  pleurisy
# PTB in the left upper field
# normal
# normal
# normal
# left PTB
# right lower field PTB
# normal
# bilateral PTB
# bilateral PTB
# normale
# STB
# normal
# normal
# normal
# secondary PTB  in the right upper field
# bilateral PTB
# Right PTB
# left secondary PTB
# normal
# secondary PTB  in the right upper field
# normal
# bilateral PTB
# PTB in the bilateral upper field
# NATB
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# PTB in the right upper field
# normal
# normal
# bilateral PTB
# normal
# bilateral PTB
# normal
# left PTB
# normal
# normal
# left PTB
# PTB in the left upper field
# normal
# normal
# normal
# Right PTB
# normal
# normal
# normal
# Bilateral secondary PTB
# left PTB
# normal
# PTB in the left lower field
# normal
# secondary PTB  in the right upper field
# normal
# PTB  in the right upper field
# normal
# normal
# normal
# bilateral PTB
# normal
# Bilateral secondary PTB
# bilateral hematogenous disseminated PTB
# normal
# normal
# normal
# normal
# secondary PTB  in the right upper field
# normal
# normal
# normal
# normal
# Right PTB
# Bilateral secondary PTB
# normal
# PTB in the bilateral upper field
# normal
# right secondary PTB
# Bilateral secondary PTB
# normal
# secondary PTB  in the right upper field
# bilateral PTB
# bilateral PTB
# normal
# normal
# normal
# Right PTB
# Right PTB
# Right PTB with fibrous changes
# bilateral PTB
# bilateral PTB
# normal
# normal
# normal
# normal
# bilateral subacute hematogenous disseminated PTB
# PTB in the middle lower field
# Bilateral secondary PTB
# normal
# Left PTB
# normal
# normal
# normal
# normal
# Bilateral secondary PTB
# bilateral PTB
# normal
# bilateral PTB
# STB
# normal
# left PTB
#
# right upper pneumonia
# normal
# normal
# Bilateral secondary PTB
# NATB
# normal
# PTB in the bilateral upper field
# secondary PTB  in the bilateral upper fields
# normal
# normal
# normal
# STB
# PTB in the bilateral upper field
#
# normal
# normal
# PTB in the right upper field
# PTB in the right upper field,COPD
# PTB in the left upper field
# Right secondary PTB
# normal
# PTB in the right upper field
# secondary PTB  in the bilateral upper field
# PTB  in the right upper field
# normal
# normal
# normal
# normal
# left secondary PTB
# PTB in the right upper field
# right secondary PTB
# normal
# PTB in the left upper field
# normal
# secondary PTB  in the left lower field
# normal
# normal
# normal
# normal
# normal
# ATB
# normal
#
# normal
# bilateral secondary PTB
# PTB in the left upper field
# normal
# normal
# normal
# normal
# PTB in the right upper field
# normal
# right secondary PTB
# normal
# normal
# right secondary PTB
# normal
# normal
# left PTB,pleural thickening
# right secondary PTB
# right upper field PTB
# normal
# bilateral PTB
# left PTB
# left PTB
# normal
# secondary PTB  in the left upper field
# Right pneumothorax, Right upper PTB, bilateral widespread infection
# right secondary PTB
# bilateral PTB
# normal
# PTB in the left upper field
# bilateral PTB
# normal
# normal
# bilateral PTB
# bilateral PTB
# left PTB
# normal
# secondary PTB in the right upper field,mainly hyperplastic lesions
# left PTB
# secondary PTB  in the bilateral upper field
# normal
# bilateral PTB, right pleurisy
# normal
# PTB in the right upper field
# secondary PTB  in the right upper field
# bilateral PTB
# normal
# bilateral PTB
# normal
# normal
# PTB in the bilateral upper field
# normal
# Right PTB
# normal
# normal
# normal
# right upper PTB
# normal
# Bilateral secondary PTB , right pleural change after decortication
# NATB
# bilateral PTB, with left pleural effusion
#
# bilateral PTB
# normal
# bilateral PTB
# right secondary PTB
# bilateral PTB ?right pleurisy with pleural effusion
# STB
# bilateral PTB
# normal
# normal
# right secondary PTB, right pleurisy with  pleural effusion
# normal
# normal
# PTB in the bilateral upper fields, left pleurisy
# Right PTB
# PTB
# normal
# normal
# normal
# bilateral PTB, right pleurisy
# bilateral PTB,  right upper lobe atelectasis
# normal
# left secondary PTB
# Bilateral secondary PTB
# Right secondary PTB,mainly hyperplastic lesions
# normal
# Right PTB
# normal
# ATB
# Right PTB
# bilateral PTB
# normal
# bilateral PTB
# normal
# normal
# bilateral PTB
# bilateral PTB
# normal
# normal
# normal
# secondary PTB  in the left upper field
# normal
# normal
# secondary PTB  in the bilateral upper field
# PTB in the right lower field
# bilateral PTB
# PTB in the right upper field
# normal
# bilateral PTB
# right upper PTB with fibrous changes
# PTB in the bilateral upper field
# normal
# left PTB
# Right PTB
# bilateral secondary PTB
# normal
# left PTB
# normal
# normal
# NATB
# normal
# normal
# 1.bilateral secondary PTB  with right upper atelectasis;2.right pleural adhesions;3.left compensatory emphysema
# PTB in the right upper field
# normal
# left PTB,left pleurisy
# normal
# left PTB
# normal
# PTB  in the right upper field
# secondary PTB  in the right upper field
# Bilateral secondary PTB
# PTB in the right lower field
# right secondary PTB
# Right PTB
# PTB in the left upper field
# normal
# secondary PTB  in the right upper field
# normal
# secondary PTB  in the right upper field
# normal
# PTB in the right upper field
# bilateral PTB
# normal
# Right PTB
# normal
# bilateral PTB
# normal
# PTB in the bilateral upper field
# bilateral secondary PTB with multiple cavitations
# Right PTB
# PTB in the left upper field
#
# normal
# right upper PTB
# Right PTB
# bilateral PTB
# normal
# normal
# normal
# normal
# secondary PTB in the right upper field
# Right secondary PTB in the upper and middle fields
# normal
# bilateral PTB
# PTB in the bilateral upper fields
# Right PTB
# normal
# normal
# PTB in the left upper field
# Bilateral secondary PTB
# normal
# secondary PTB in the bilateral upper field
# bilateral PTB
# secondary PTB  in thel left upper field
# normal
#
# normal
# normal
# PTB in the left upper field
# Right PTB
# normal
# normal
# normal
# Right PTB
# bilateral PTB
# bilateral PTB
# normal
# normal
# normal
# bilateral PTB
# normal
# normal
# right PTB,right pneumothorax
# normal
# Old PTB in the right upper field
# bilateral PTB
# tuberculosis pleuritis
# secondary PTB  in the bilateral upper field
# normal
# normal
# normal
# PTB in the right upper field
# normal
# normal
# normal
# normal
# normal
# normal
# PTB in the left upper field
# bilateral PTB, with cavity formation in right upper field
# left PTB
# bilateral PTB
#  normal
# Bilateral secondary PTB  with most lesions calcified
# right upper PTB, pleural adhesions in  left lower field
# normal
# normal
# normal
# normal
# normal
# normal
# PTB in the right upper field
# PTB in the right upper field
# normal
# normal
# normal
# Bilateral secondary PTB
# normal
# normal
# normal
# STB
# normal
# PTB in the right upper field
# normal
# normal
# Left PTB, left pleural thickening
# Right PTB
# bilateral PTB
# Right PTB
# STB
# normal
# normal
# normal
# normal
# normal
# Right PTB
# normal
# normal
# secondary PTB  in the left upper field
# bilateral secondary PTB,mainly hyperplastic lesions
# normal
# PTB in the left lower field
# bilateral PTB
# normal
# normal
# Right PTB
# normal
#
# Right PTB
# normal
# normal
# normal
# left PTB
# normal
# bilateral PTB
# normal
# Right PTB
# normal
# normal
# Bilateral secondary PTB
# normal
# Right PTB
# normal
# normal
# normal
# secondary PTB  in the left upper field
# Right PTB
# Right PTB
# normal
# secondary PTB  in the bilateral upper fields
# Right PTB
# Right PTB
# normal
# right upper PTB
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# left PTB,left pleurisy
# normal
# Old PTB in the right upper field
#
# secondary PTB  in the bilateral upper field
# normal
# NATB
# Right PTB
# normal
# normal
# Right PTB
# normal
# bilateral PTB,right upper field atelectasis
# secondary PTB  in the right upper field
# Right PTB
# normal
# Bilateral secondary PTB
# PTB
# normal
# secondary PTB  in the right  middle field
# bilateral PTB
# left secondary PTB,right pleural effusion
# bilateral PTB
# bilateral acute hematogenous disseminated PTB
# normal
# STB
#
# normal
# PTB in the left upper field
# normal
# normal
# PTB in the left upper field
# PTB in the bilateral upper and middle field
# Bilateral secondary PTB
# PTB in the right upper field
# normal
# normal
# secondary PTB in the bilateral upper and middle fields, mainly fibrous  lesions
# normal
# PTB in the left upper field
# normal
# secondary PTB  in the right upper field
# PTB in the left upper field
# normal
# normal
# normal
# normal
# PTB in the right upper field
# bilateral PTB
# normal
# PTB in the left upper field
# right secondary PTB
# normal
# normal
# normal
# PTB in the right upper field
# bilateral PTB
# normal
# PTB in the right upper field
# normal
# normal
# left PTB
# normal
# Bilateral secondary PTB
# PTB in the bilateral upper fields
# normal
# PTB in the right upper field
# normal
# right lower field PTB
# secondary PTB  in the left upper field
# normal
# normal
# normal
# Right PTB
# Bilateral secondary PTB
# bilateral PTB
# bilateral PTB
# Bilateral secondary PTB, left encapsulated intrathoracic fluid
# normal
# normal
# TB
# secondary PTB  in the bilateral upper field
# Right PTB
# normal
# normal
# bilateral PTB
# Right PTB
# normal
# normal
# PTB in the bilateral upper field
# PTB in the bilateral upper fields
# Right PTB
# normal
# bilateral PTB
# normal
# PTB in the right upper field
# normal
# normal
# PTB in the right lower field
# bilateral PTB
# PTB in the right upper field
# normal
# Left PTB
# normal
# Right PTB
# bilateral PTB
# normal
# bilateral PTB
# ATB
# normal
# normal
# PTB in the right upper field
# bilateral PTB
# normal
# normal
# normal
# normal
# right upper PTB
# Right PTB
# normal
# normal
# normal
# normal
# Right PTB

# %%
#path to images
img_dir = "../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles"
data_dir2 = "../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/ClinicalReadings"

#list all available images type
print(os.listdir(img_dir))
print(os.listdir(data_dir2))
# Out:
# ['ClinicalReadings', 'NLM-ChinaCXRSet-ReadMe.docx', 'CXR_png']
# ['CHNCXR_0022_0.txt', 'CHNCXR_0601_1.txt', 'CHNCXR_0014_0.txt', 'CHNCXR_0416_1.txt', 'CHNCXR_0097_0.txt', 'CHNCXR_0535_1.txt', 'CHNCXR_0614_1.txt', 'CHNCXR_0593_1.txt', 'CHNCXR_0436_1.txt', 'CHNCXR_0308_0.txt', 'CHNCXR_0052_0.txt', 'CHNCXR_0094_0.txt', 'CHNCXR_0019_0.txt', 'CHNCXR_0099_0.txt', 'CHNCXR_0286_0.txt', 'CHNCXR_0566_1.txt', 'CHNCXR_0275_0.txt', 'CHNCXR_0281_0.txt', 'CHNCXR_0215_0.txt', 'CHNCXR_0133_0.txt', 'CHNCXR_0288_0.txt', 'CHNCXR_0658_1.txt', 'CHNCXR_0257_0.txt', 'CHNCXR_0226_0.txt', 'CHNCXR_0661_1.txt', 'CHNCXR_0394_1.txt', 'CHNCXR_0037_0.txt', 'CHNCXR_0509_1.txt', 'CHNCXR_0183_0.txt', 'CHNCXR_0462_1.txt', 'CHNCXR_0398_1.txt', 'CHNCXR_0181_0.txt', 'CHNCXR_0644_1.txt', 'CHNCXR_0346_1.txt', 'CHNCXR_0597_1.txt', 'CHNCXR_0570_1.txt', 'CHNCXR_0327_1.txt', 'CHNCXR_0552_1.txt', 'CHNCXR_0088_0.txt', 'CHNCXR_0585_1.txt', 'CHNCXR_0277_0.txt', 'CHNCXR_0607_1.txt', 'CHNCXR_0653_1.txt', 'CHNCXR_0608_1.txt', 'CHNCXR_0236_0.txt', 'CHNCXR_0270_0.txt', 'CHNCXR_0145_0.txt', 'CHNCXR_0137_0.txt', 'CHNCXR_0527_1.txt', 'CHNCXR_0599_1.txt', 'CHNCXR_0650_1.txt', 'CHNCXR_0407_1.txt', 'CHNCXR_0075_0.txt', 'CHNCXR_0496_1.txt', 'CHNCXR_0121_0.txt', 'CHNCXR_0003_0.txt', 'CHNCXR_0378_1.txt', 'CHNCXR_0235_0.txt', 'CHNCXR_0203_0.txt', 'CHNCXR_0503_1.txt', 'CHNCXR_0050_0.txt', 'CHNCXR_0645_1.txt', 'CHNCXR_0434_1.txt', 'CHNCXR_0513_1.txt', 'CHNCXR_0325_0.txt', 'CHNCXR_0356_1.txt', 'CHNCXR_0353_1.txt', 'CHNCXR_0160_0.txt', 'CHNCXR_0518_1.txt', 'CHNCXR_0084_0.txt', 'CHNCXR_0131_0.txt', 'CHNCXR_0002_0.txt', 'CHNCXR_0586_1.txt', 'CHNCXR_0175_0.txt', 'CHNCXR_0638_1.txt', 'CHNCXR_0435_1.txt', 'CHNCXR_0069_0.txt', 'CHNCXR_0347_1.txt', 'CHNCXR_0461_1.txt', 'CHNCXR_0625_1.txt', 'CHNCXR_0280_0.txt', 'CHNCXR_0596_1.txt', 'CHNCXR_0117_0.txt', 'CHNCXR_0632_1.txt', 'CHNCXR_0032_0.txt', 'CHNCXR_0602_1.txt', 'CHNCXR_0455_1.txt', 'CHNCXR_0619_1.txt', 'CHNCXR_0141_0.txt', 'CHNCXR_0194_0.txt', 'CHNCXR_0300_0.txt', 'CHNCXR_0444_1.txt', 'CHNCXR_0595_1.txt', 'CHNCXR_0119_0.txt', 'CHNCXR_0594_1.txt', 'CHNCXR_0603_1.txt', 'CHNCXR_0059_0.txt', 'CHNCXR_0340_1.txt', 'CHNCXR_0305_0.txt', 'CHNCXR_0248_0.txt', 'CHNCXR_0018_0.txt', 'CHNCXR_0363_1.txt', 'CHNCXR_0406_1.txt', 'CHNCXR_0551_1.txt', 'CHNCXR_0641_1.txt', 'CHNCXR_0307_0.txt', 'CHNCXR_0642_1.txt', 'CHNCXR_0105_0.txt', 'CHNCXR_0575_1.txt', 'CHNCXR_0399_1.txt', 'CHNCXR_0334_1.txt', 'CHNCXR_0086_0.txt', 'CHNCXR_0125_0.txt', 'CHNCXR_0092_0.txt', 'CHNCXR_0321_0.txt', 'CHNCXR_0225_0.txt', 'CHNCXR_0211_0.txt', 'CHNCXR_0202_0.txt', 'CHNCXR_0124_0.txt', 'CHNCXR_0536_1.txt', 'CHNCXR_0206_0.txt', 'CHNCXR_0290_0.txt', 'CHNCXR_0491_1.txt', 'CHNCXR_0042_0.txt', 'CHNCXR_0606_1.txt', 'CHNCXR_0163_0.txt', 'CHNCXR_0605_1.txt', 'CHNCXR_0238_0.txt', 'CHNCXR_0049_0.txt', 'CHNCXR_0581_1.txt', 'CHNCXR_0539_1.txt', 'CHNCXR_0184_0.txt', 'CHNCXR_0109_0.txt', 'CHNCXR_0165_0.txt', 'CHNCXR_0433_1.txt', 'CHNCXR_0100_0.txt', 'CHNCXR_0190_0.txt', 'CHNCXR_0106_0.txt', 'CHNCXR_0610_1.txt', 'CHNCXR_0562_1.txt', 'CHNCXR_0313_0.txt', 'CHNCXR_0488_1.txt', 'CHNCXR_0294_0.txt', 'CHNCXR_0628_1.txt', 'CHNCXR_0269_0.txt', 'CHNCXR_0371_1.txt', 'CHNCXR_0028_0.txt', 'CHNCXR_0023_0.txt', 'CHNCXR_0207_0.txt', 'CHNCXR_0497_1.txt', 'CHNCXR_0265_0.txt', 'CHNCXR_0465_1.txt', 'CHNCXR_0555_1.txt', 'CHNCXR_0074_0.txt', 'CHNCXR_0164_0.txt', 'CHNCXR_0053_0.txt', 'CHNCXR_0008_0.txt', 'CHNCXR_0627_1.txt', 'CHNCXR_0128_0.txt', 'CHNCXR_0004_0.txt', 'CHNCXR_0155_0.txt', 'CHNCXR_0296_0.txt', 'CHNCXR_0512_1.txt', 'CHNCXR_0423_1.txt', 'CHNCXR_0013_0.txt', 'CHNCXR_0480_1.txt', 'CHNCXR_0292_0.txt', 'CHNCXR_0451_1.txt', 'CHNCXR_0447_1.txt', 'CHNCXR_0186_0.txt', 'CHNCXR_0631_1.txt', 'CHNCXR_0558_1.txt', 'CHNCXR_0561_1.txt', 'CHNCXR_0041_0.txt', 'CHNCXR_0289_0.txt', 'CHNCXR_0085_0.txt', 'CHNCXR_0617_1.txt', 'CHNCXR_0524_1.txt', 'CHNCXR_0402_1.txt', 'CHNCXR_0384_1.txt', 'CHNCXR_0439_1.txt', 'CHNCXR_0120_0.txt', 'CHNCXR_0192_0.txt', 'CHNCXR_0122_0.txt', 'CHNCXR_0213_0.txt', 'CHNCXR_0600_1.txt', 'CHNCXR_0498_1.txt', 'CHNCXR_0458_1.txt', 'CHNCXR_0047_0.txt', 'CHNCXR_0495_1.txt', 'CHNCXR_0 ...

# %%
def load_data(img_dir,data_dir2):
    X = []
    y = []
    labels = []
    idx = 0
    for i,folder_name in enumerate(os.listdir(img_dir)):
        if folder_name in ( "CXR_png"):
            for file_name in tqdm(os.listdir(f'{img_dir}/{folder_name}')):
                if file_name.endswith('png'):
                    #print(file_name)
                    f = open('../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/ClinicalReadings/'+file_name[:-4]+'.txt', 'r')
                    file_contents = f.read()
                    file_con_list = file_contents.split("\n")
                    file_con_list = file_con_list[-1]
                    if "normal" in file_con_list:
                        file_con_list = "normal"
                    else:
                        file_con_list = "PTB"
                    #print (file_con_list)
                    if file_con_list not in labels:
                        labels.append(file_con_list)
                    im = cv2.imread(f'{img_dir}/{folder_name}/{file_name}')
                    if im is not None:
                        im = cv2.resize(im, (100, 100))
                        X.append(im)
                        y.append(labels.index(file_con_list))

    
    X = np.asarray(X)
    y = np.asarray(y)
    labels = np.asarray(labels)
    return X,y,labels

def load_data1(img_dir2):
    X = []
    y = []
    labels = []
    idx = 2
    for i,folder_name in enumerate(os.listdir(img_dir2)):
        #here we get validation and train
        for j,folder_name1 in enumerate(os.listdir(os.path.join(img_dir2,folder_name))):
            if folder_name1 in ( "humans"):
                if folder_name1 not in labels:
                    labels.append(folder_name)
                for file_name in tqdm(os.listdir(f'{img_dir2}/{folder_name}/{folder_name1}')):
                    if file_name.endswith('png'):
                        im = io.imread(f'{img_dir2}/{folder_name}/{folder_name1}/{file_name}')
                    if im is not None:
                        im = transform.resize(im, (100, 100))
                        X.append(im)
                        y.append(idx)
            
    
    X = np.asarray(X)
    y = np.asarray(y)
    labels = np.asarray(labels)
    return X,y,labels

# %%
X,y,labels = load_data(img_dir,data_dir2)
#X1,y1,labels1 = load_data1(img_dir2)
#X,y,labels = X2,y2,labels1+labels2
# Out:
# 100%|██████████| 663/663 [01:06<00:00,  9.05it/s]

# %%
#fix y
y = y.reshape(-1,1)

# %%
for i,_ in enumerate(y):
    if y[i] == 1:
        y[i]=0
    elif y[i] == 2:
        pass
    else:
        y[i]=1

print(y[0])
# Out:
# [1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
train_img = X_train
train_labels = y_train
test_img = X_test
test_labels = y_test
train_img.shape, train_labels.shape, test_img.shape, test_labels.shape
# Out:
# ((529, 100, 100, 3), (529, 1), (133, 100, 100, 3), (133, 1))

# %%
#show random samples
rand_14 = np.random.randint(0, train_img.shape[0],14)
sample_img = train_img[rand_14]
sample_labels = train_labels[rand_14]
num_rows, num_cols = 2, 7
f, ax = plt.subplots(num_rows, num_cols, figsize=(12,5),gridspec_kw={'wspace':0.03, 'hspace':0.01})
for r in range(num_rows):
    for c in range(num_cols):
        image_index = r * 7 + c
        ax[r,c].axis("off")
        ax[r,c].imshow(sample_img[image_index])
        ax[r,c].set_title('%s' % sample_labels[image_index])
plt.show()
plt.close()
print(labels)
# Out:
# ['PTB' 'normal']

# %%
#one-hot-encode the labels
num_classes = len(labels)
train_labels_cat = to_categorical(train_labels,num_classes)
test_labels_cat = to_categorical(test_labels,num_classes)
train_labels_cat.shape, test_labels_cat.shape
# Out:
# ((529, 2), (133, 2))

# %%
# re-shape the images data
train_data = train_img
test_data = test_img
train_data.shape, test_data.shape
# Out:
# ((529, 100, 100, 3), (133, 100, 100, 3))

# %%
# shuffle the training dataset & set aside val_perc % of rows as validation data
for _ in range(5): 
    indexes = np.random.permutation(len(train_data))

# randomly sorted!
train_data = train_data[indexes]
train_labels_cat = train_labels_cat[indexes]

# now we will set-aside val_perc% of the train_data/labels as cross-validation sets
val_perc = 0.10
val_count = int(val_perc * len(train_data))
print(val_count)

# first pick validation set
val_data = train_data[:val_count,:]
val_labels_cat = train_labels_cat[:val_count,:]

# leave rest in training set
train_data2 = train_data[val_count:,:]
train_labels_cat2 = train_labels_cat[val_count:,:]

train_data2.shape, train_labels_cat2.shape, val_data.shape, val_labels_cat.shape, test_data.shape, test_labels_cat.shape
# Out:
# 52
# ((477, 100, 100, 3),
#  (477, 2),
#  (52, 100, 100, 3),
#  (52, 2),
#  (133, 100, 100, 3),
#  (133, 2))

# %%
# a utility function that plots the losses and accuracies for training & validation sets across our epochs
def show_plots(history):
    """ Useful function to view plot of loss values & accuracies across the various epochs """
    loss_vals = history['loss']
    val_loss_vals = history['val_loss']
    epochs = range(1, len(history['acc'])+1)
    
    f, ax = plt.subplots(nrows=1,ncols=2,figsize=(16,4))
    
    # plot losses on ax[0]
    ax[0].plot(epochs, loss_vals, color='navy',marker='o', linestyle=' ', label='Training Loss')
    ax[0].plot(epochs, val_loss_vals, color='firebrick', marker='*', label='Validation Loss')
    ax[0].set_title('Training & Validation Loss')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend(loc='best')
    ax[0].grid(True)
    
    # plot accuracies
    acc_vals = history['acc']
    val_acc_vals = history['val_acc']

    ax[1].plot(epochs, acc_vals, color='navy', marker='o', ls=' ', label='Training Accuracy')
    ax[1].plot(epochs, val_acc_vals, color='firebrick', marker='*', label='Validation Accuracy')
    ax[1].set_title('Training & Validation Accuracy')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Accuracy')
    ax[1].legend(loc='best')
    ax[1].grid(True)
    
    plt.show()
    plt.close()
    
    # delete locals from heap before exiting
    del loss_vals, val_loss_vals, epochs, acc_vals, val_acc_vals

# %%
def print_time_taken(start_time, end_time):
    secs_elapsed = end_time - start_time
    
    SECS_PER_MIN = 60
    SECS_PER_HR  = 60 * SECS_PER_MIN
    
    hrs_elapsed, secs_elapsed = divmod(secs_elapsed, SECS_PER_HR)
    mins_elapsed, secs_elapsed = divmod(secs_elapsed, SECS_PER_MIN)
    
    if hrs_elapsed > 0:
        print('Time taken: %d hrs %d mins %d secs' % (hrs_elapsed, mins_elapsed, secs_elapsed))
    elif mins_elapsed > 0:
        print('Time taken: %d mins %d secs' % (mins_elapsed, secs_elapsed))
    elif secs_elapsed > 1:
        print('Time taken: %d secs' % (secs_elapsed))
    else:
        print('Time taken - less than 1 sec')

# %%
def get_commonname(idx):
    sciname = labels[idx]
    return sciname

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


import numpy as np
from keras.utils.np_utils import to_categorical

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization,Activation,MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.datasets import mnist
from keras.models import load_model
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from PIL import Image

# %%
#data augmentation
datagen = ImageDataGenerator(
        rotation_range=30,
        zoom_range = 0.25,  
        width_shift_range=0.1, 
        height_shift_range=0.1)
# datagen = ImageDataGenerator(
#     rotation_range=8,
#     shear_range=0.3,
#     zoom_range = 0.08,
#     width_shift_range=0.08,
#     height_shift_range=0.08)

# %%
#create multiple cnn model for ensembling
#model 1
model = Sequential()

model.add(Conv2D(32, kernel_size = 3, activation='relu', input_shape = (100, 100, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size = 3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size = 5, strides=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(64, kernel_size = 3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size = 3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size = 5, strides=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size = 3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size = 3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size = 5, strides=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))


model.add(Conv2D(256, kernel_size = 4, activation='relu'))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(num_classes, activation='softmax'))

# use adam optimizer and categorical cross entropy cost
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
# after each epoch decrease learning rate by 0.95
annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x)

# train
epochs = 50
j=0
start_time = time.time()
history = model.fit_generator(datagen.flow(train_data2, train_labels_cat2, batch_size=64),epochs = epochs, steps_per_epoch = train_data2.shape[0]/64,validation_data = (val_data, val_labels_cat), callbacks=[annealer], verbose=1)
end_time = time.time()
print_time_taken(start_time, end_time)


print("CNN {0:d}: Epochs={1:d}, Train accuracy={2:.5f}, Validation accuracy={3:.5f}".format(j+1,epochs,history.history['acc'][epochs-1],history.history['val_acc'][epochs-1]))
# Out:
# Epoch 1/50
# 8/7 [================================] - 4s 535ms/step - loss: 1.0896 - acc: 0.6284 - val_loss: 3.7726 - val_acc: 0.4423
# Epoch 2/50
# 8/7 [================================] - 1s 66ms/step - loss: 1.3564 - acc: 0.6226 - val_loss: 0.9590 - val_acc: 0.7692
# Epoch 3/50
# 8/7 [================================] - 1s 90ms/step - loss: 1.1646 - acc: 0.6501 - val_loss: 2.8550 - val_acc: 0.6538
# Epoch 4/50
# 8/7 [================================] - 1s 135ms/step - loss: 1.0995 - acc: 0.6740 - val_loss: 1.0987 - val_acc: 0.7115
# Epoch 5/50
# 8/7 [================================] - 1s 137ms/step - loss: 1.0434 - acc: 0.6839 - val_loss: 1.8067 - val_acc: 0.7500
# Epoch 6/50
# 8/7 [================================] - 1s 140ms/step - loss: 0.8905 - acc: 0.7050 - val_loss: 1.6709 - val_acc: 0.7885
# Epoch 7/50
# 8/7 [================================] - 1s 140ms/step - loss: 0.9527 - acc: 0.7111 - val_loss: 1.8048 - val_acc: 0.7500
# Epoch 8/50
# 8/7 [================================] - 1s 136ms/step - loss: 0.7357 - acc: 0.7116 - val_loss: 1.4784 - val_acc: 0.8269
# Epoch 9/50
# 8/7 [================================] - 1s 136ms/step - loss: 0.8322 - acc: 0.7095 - val_loss: 0.9091 - val_acc: 0.7115
# Epoch 10/50
# 8/7 [================================] - 1s 138ms/step - loss: 0.7828 - acc: 0.6976 - val_loss: 2.0632 - val_acc: 0.6346
# Epoch 11/50
# 8/7 [================================] - 1s 138ms/step - loss: 0.7349 - acc: 0.7376 - val_loss: 0.7931 - val_acc: 0.6538
# Epoch 12/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.7200 - acc: 0.7555 - val_loss: 0.6466 - val_acc: 0.7115
# Epoch 13/50
# 8/7 [================================] - 1s 135ms/step - loss: 0.6653 - acc: 0.7372 - val_loss: 1.1659 - val_acc: 0.6538
# Epoch 14/50
# 8/7 [================================] - 1s 139ms/step - loss: 0.7804 - acc: 0.7130 - val_loss: 0.5913 - val_acc: 0.7885
# Epoch 15/50
# 8/7 [================================] - 1s 138ms/step - loss: 0.6917 - acc: 0.7116 - val_loss: 1.0209 - val_acc: 0.6346
# Epoch 16/50
# 8/7 [================================] - 1s 139ms/step - loss: 0.6443 - acc: 0.7531 - val_loss: 0.7791 - val_acc: 0.7308
# Epoch 17/50
# 8/7 [================================] - 1s 136ms/step - loss: 0.6179 - acc: 0.7790 - val_loss: 0.9965 - val_acc: 0.7115
# Epoch 18/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.7027 - acc: 0.7216 - val_loss: 0.8089 - val_acc: 0.7115
# Epoch 19/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.6020 - acc: 0.7771 - val_loss: 0.4027 - val_acc: 0.8077
# Epoch 20/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.6688 - acc: 0.7530 - val_loss: 0.4589 - val_acc: 0.7885
# Epoch 21/50
# 8/7 [================================] - 1s 144ms/step - loss: 0.6453 - acc: 0.7371 - val_loss: 0.5327 - val_acc: 0.7500
# Epoch 22/50
# 8/7 [================================] - 1s 138ms/step - loss: 0.6174 - acc: 0.7309 - val_loss: 0.5743 - val_acc: 0.7308
# Epoch 23/50
# 8/7 [================================] - 1s 141ms/step - loss: 0.6716 - acc: 0.7408 - val_loss: 1.9390 - val_acc: 0.4231
# Epoch 24/50
# 8/7 [================================] - 1s 142ms/step - loss: 0.7580 - acc: 0.7057 - val_loss: 1.3684 - val_acc: 0.5385
# Epoch 25/50
# 8/7 [================================] - 1s 140ms/step - loss: 0.6290 - acc: 0.7708 - val_loss: 0.9472 - val_acc: 0.7500
# Epoch 26/50
# 8/7 [================================] - 1s 141ms/step - loss: 0.7354 - acc: 0.7345 - val_loss: 0.5764 - val_acc: 0.7308
# Epoch 27/50
# 8/7 [================================] - 1s 142ms/step - loss: 0.6025 - acc: 0.7452 - val_loss: 0.5121 - val_acc: 0.7692
# Epoch 28/50
# 8/7 [================================] - 1s 142ms/step - loss: 0.5665 - acc: 0.7666 - val_loss: 1.1520 - val_acc: 0.7308
# Epoch 29/50
# 8/7 [================================] - 1s 142ms/step - loss: 0.5983 - acc: 0.7547 - val_loss: 0.8273 - val_acc: 0.7692
# Epoch 30/50
# 8/7 [================================] - 1s 139ms/step - loss: 0.6169 - acc: 0.7490 - val_loss: 1.0245 - val_acc: 0.7500
# Epoch 31/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.6838 - acc: 0.7430 - val_loss: 0.7681 - val_acc: 0.7692
# Epoch 32/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.7299 - acc: 0.7366 - val_loss: 0.6742 - val_acc: 0.7308
# Epoch 33/50
# 8/7 [================================] - 1s 138ms/step - loss: 0.6549 - acc: 0.7664 - val_loss: 0.6059 - val_acc: 0.7692
# Epoch 34/50
# 8/7 [================================] - 1s 138ms/step - loss: 0.6084 - acc: 0.7627 - val_loss: 0.7748 - val_acc: 0.7115
# Epoch 35/50
# 8/7 [================================] - 1s 137ms/step - loss: 0.6010 - acc: 0.7746 - val_loss: 0.7927 - val_acc: 0.8077
# Epoch 36/50
# 8/7 [================================] - 1s 139ms/step - loss: 0.5452 - acc: 0.7705 - val_loss: 0.7474 - val_acc: 0.7885
# Epoch 37/50
# 8/7 [================================] - 1s 139ms/step - loss: 0.6064 - acc: 0.7447 - val_loss: 0.5672 - val_acc: 0.8077
# Epoch 38/50
# 8/7 [================================] - 1s 144ms/step - loss: 0.5666 - acc: 0.7690 - val_loss: 0.5071 - val_acc: 0.7500
# Epoch 39/50
# 8/7 [================================] - 1s 144ms/step - loss: 0.5733 - acc: 0.7792 - val_loss: 0.5050 - val_acc: 0.7308
# Epoch 40/50
# 8/7 [================================] - 1s 143ms/step - loss: 0.6047 - acc: 0.7670 - val_loss: 0.5465 - val_acc: 0.7308
# Epoch 41/50
# 8/7 [================================] - 1s 143ms/step - loss: 0.5223 - acc: 0.7707 - val_loss: 0.5951 - val_acc: 0.7500
# Epoch 42/50
# 8/7 [================================] - 1s 141ms/step - loss: 0.5020 - acc: 0.7744 - val_loss: 0.6830 - val_acc: 0.7308
# Epoch 43/50
# 8/7 [================================] - 1s 142ms/step - loss: 0.5708 - acc: 0.7845 - val_loss: 0.6870 - val_acc: 0.7500
# Epoch 44/50
# 8/7 [================================] - 1s 139ms/step - loss: 0.5290 - acc: 0.7552 - val_loss: 0.6592 - val_acc: 0.7692
# Epoch 45/50
# 8/7 [================================] - 1s 145ms/step - loss: 0.5815 - acc: 0.7585 - val_loss: 0.5821 - val_acc: 0.7500
# Epoch 46/50
# 8/7 [================================] - 1s 143ms/step - loss: 0.5998 - acc: 0.7488 - val_loss: 0.6145 - val_acc: 0.7500
# Epoch 47/50
# 8/7 [================================] - 1s 143ms/step - loss: 0.5222 - acc: 0.7887 - val_loss: 0.6476 - val_acc: 0.7308
# Epoch 48/50
# 8/7 [================================] - 1s 147ms/step - loss: 0.5394 - acc: 0.7769 - val_loss: 0.6049 - val_acc: 0.7500
# Epoch 49/50
# 8/7 [================================] - 1s 142ms/step - loss: 0.5576 - acc: 0.7728 - val_loss: 0.5683 - val_acc: 0.7500
# Epoch 50/50
# 8/7 [================================] - 1s 140ms/step - loss: 0.5513 - acc: 0.7908 - val_loss: 0.5632 - val_acc: 0.7500
# Time taken: 1 mins 0 secs
# CNN 1: Epochs=50, Train accuracy=0.78616, Validation accuracy=0.75000

# %%
show_plots(history.history)

# %%
test_loss, test_accuracy = model.evaluate(test_data, test_labels_cat, batch_size=64)
print('Test loss: %.4f accuracy: %.4f' % (test_loss, test_accuracy))
# Out:
# 133/133 [==============================] - 0s 403us/step
# Test loss: 0.5052 accuracy: 0.7669

# %%
im_list = [100,13,14,15]
for i in im_list:
#     i = 1000  #index from test data to be used, change this other value to see a different image
    img = test_data[i]
    plt.imshow(img)
    plt.show()
    pred = model.predict_classes(img.reshape(-1,100,100,3))
    actual =  test_labels[i]
    print(f'actual: {get_commonname(actual)}')
    print(f'predicted: {get_commonname(pred)}')
# Out:
# actual: ['normal']
# predicted: ['normal']
# actual: ['PTB']
# predicted: ['PTB']
# actual: ['PTB']
# predicted: ['PTB']
# actual: ['PTB']
# predicted: ['PTB']

# %%
#matrix = metrics.confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
preds = model.predict(test_data, batch_size=16)
preds = np.argmax(preds, axis=-1)

# Original labels
orig_test_labels = np.argmax(test_labels, axis=-1)

print(orig_test_labels.shape)
print(preds.shape)

cm  = confusion_matrix(orig_test_labels, preds)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(2), ['PTB','normal'], fontsize=8) 
plt.yticks(range(2), ['PTB','normal'], fontsize=8)
plt.show()
# Out:
# (133,)
# (133,)
# /opt/conda/lib/python3.6/site-packages/mlxtend/plotting/plot_confusion_matrix.py:66: RuntimeWarning: invalid value encountered in true_divide
#   normed_conf_mat = conf_mat.astype('float') / total_samples

# %%
from keras.models import model_from_json
from keras.models import load_model

# serialize model to JSON
#  the keras model which is trained is defined as 'model' in this example
model_json = model.to_json()


with open("model_4.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights("model_4.h5")
